# %% [markdown]
# <a href="https://colab.research.google.com/github/sarvesh238327109/DataScience_Internship/blob/main/Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('/content/creditcard.csv')

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (17918, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 26

# %%
print(df.columns) # df.columns is an Index object, not a callable method.
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_csv('/content/creditcard.csv')

# Display the counts of each class (0 and 1) in the 'Class' column
class_counts = dataset['Class'].value_counts()
print(class_counts)

# Alternatively, you can also print the counts separately
num_normal = class_counts[0]
num_fraudulent = class_counts[1]

print(f'Number of normal transactions: {num_normal}')
print(f'Number of fraudulent transactions: {num_fraudulent}')
# Out:
# Class
# 0.0    59348
# 1.0      162
# Name: count, dtype: int64
# Number of normal transactions: 59348
# Number of fraudulent transactions: 162

# %% [markdown]
# **Data Visualisation**

# %% [markdown]
# Pie Chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/creditcard.csv')

# Count the occurrences of each class
class_counts = df['Class'].value_counts()

# Define labels and sizes
labels = ['Normal', 'Fraudulent']
sizes = class_counts.values
colors = ['skyblue', 'salmon']
explode = (0, 0.1)  # explode the 2nd slice (Fraudulent)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140)
plt.title('Proportion of Normal vs Fraudulent Transactions')
plt.show()

# %% [markdown]
# Bar Chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/creditcard.csv')

# Count the occurrences of each class
class_counts = df['Class'].value_counts()

# Define labels and sizes
labels = ['Normal', 'Fraudulent']
sizes = class_counts.values

# Plot the bar chart
plt.figure(figsize=(10, 7))
plt.bar(labels, sizes, color=['skyblue', 'salmon'])
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.title('Distribution of Normal vs Fraudulent Transactions')
plt.show()

# %% [markdown]
# Histogram

# %%
import pandas as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/creditcard.csv')

# Create a histogram for the 'Amount' column
plt.figure(figsize=(10, 7))
plt.hist(df['Amount'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Transaction Amounts')
plt.grid(axis='y')  # Add gridlines only along the y-axis for clarity
plt.show()

# %% [markdown]
# Scatter Plot

# %%
import pandas as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/creditcard.csv')

# Create a scatter plot between 'Amount' and 'Time'
plt.figure(figsize=(10, 7))
plt.scatter(df['Time'], df['Amount'], alpha=0.5, color='skyblue', edgecolor='w', linewidth=0.5)
plt.xlabel('Time')
plt.ylabel('Transaction Amount')
plt.title('Scatter Plot of Transaction Amount vs Time')
plt.grid(True)
plt.show()

# %% [markdown]
# Heat map

# %%
import pandas as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('/content/creditcard.csv')

# Compute the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# **Data Engineering**

# %% [markdown]
# 1. Dealing with null values

# %%
df.isnull().sum().sum()
# Out:
# 19

# %%
# Fill NaN values with the mean of each column
df1 = df.fillna(df.mean())

df1
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 114957  73690 -2.197480  1.982629  0.259502  0.924323 -0.879938 -0.135952
# 114958  73690 -2.197480  1.982629  0.259502  0.924323 -0.879938 -0.135952
# 114959  73690  1.255655  0.293362  0.288616  0.701727 -0.447134 -1.093442
# 114960  73690  1.270638 -0.089535 -0.990690 -0.375303  0.652307 -0.073908
# 114961  73691  1.295784  0.049457 -1.301814 -0.476648  2.131357  3.184446
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 2. Dealing with Outliers

# %% [markdown]
# Z-score method

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Calculate Z-scores
z_scores = np.abs(stats.zscore(df1))

# Define a threshold for identifying outliers
threshold = 3

# Identify outliers
outliers_z = np.where(z_scores > threshold)
outliers_df_z = df1[(z_scores > threshold).any(axis=1)]

print("Outliers based on Z-score method:")
outliers_df_z
# Out:
# Outliers based on Z-score method:
#          Time        V1        V2        V3        V4        V5        V6  \
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 7           7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 18         14 -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406
# 38         29  0.996370 -0.122589  0.546819  0.706580  0.134560  1.156995
# 51         36 -1.004929 -0.985978 -0.038039  3.710061 -6.631951  5.122103
# ...       ...       ...       ...       ...       ...       ...       ...
# 114908  73669 -1.357674  0.711068  1.139583 -2.199350 -1.362423  0.666917
# 114927  73678 -2.609113  2.822918  0.712443  1.048814 -0.934928  0.558516
# 114948  73686  1.236625 -0.488199 -0.182822 -0.796193  0.020213  0.451013
# 114953  73688 -5.180411 -5.829494  1.619778  0.331152  6.251576 -4.538414
# 114954  73689  0.023099  0.471648  0.359343 -0.788264  0.362579 -0.371379
#
# ...

# %% [markdown]
# IQR method

# %%
Q1 = df1.quantile(0.25)
Q3 = df1.quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers_iqr = df1[((df1 < (Q1 - 1.5 * IQR)) | (df1 > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Outliers based on IQR method:")
outliers_iqr
# Out:
# Outliers based on IQR method:
#          Time        V1        V2        V3        V4        V5        V6  \
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 7           7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8           7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# ...       ...       ...       ...       ...       ...       ...       ...
# 114955  73690 -2.200286  1.978209  0.261465  0.925409 -0.869958 -0.142739
# 114956  73690 -2.200286  1.978209  0.261465  0.925409 -0.869958 -0.142739
# 114957  73690 -2.197480  1.982629  0.259502  0.924323 -0.879938 -0.135952
# 114958  73690 -2.197480  1.982629  0.259502  0.924323 -0.879938 -0.135952
# 114961  73691  1.295784  0.049457 -1.301814 -0.476648  2.131357  3.184446
#
# ...

# %% [markdown]
# 3. Convert Numeric values to Categorical values

# %%
# prompt: Convert Numeric values to Categorical values

df2=df1.copy()
# Create a dictionary to map numeric values to categories
mapping = {
  0: 'Normal',
  1: 'Fraudulent'
}

# Apply the mapping to the 'Class' column
df2['Class'] = df1['Class'].map(mapping)

# Print the first few rows of the dataframe
df2.head()


# here only the target variable has turned from numeric to Categorical
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df3=df1.copy()
df3.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 4. Dealing with Imbalance

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
dataset4 = dataset.copy()

# Check the distribution of the target variable
sns.countplot(x='Class', data=df3)

plt.title('Bankruptcy prediction')
plt.show()

# Print value counts
print(df3['Class'].value_counts())
# Out:
# Class
# 0.000000    114719
# 1.000000       242
# 0.002105         1
# Name: count, dtype: int64

# %% [markdown]
# Using SMOTE Oversampling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

df1 = pd.read_csv('/content/creditcard.csv')

# Copy the data
df4 = df1.copy()

# Separate features (only numeric columns) and target
numeric_cols = df4.select_dtypes(include='number').columns
X = df4[numeric_cols]
y = df4['Class']  # Assuming 'Class' is the column indicating fraud (1) or not (0)

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check the distribution after resampling
plt.figure(figsize=(8, 6))
sns.countplot(x=y_train_resampled)
plt.title('Class Distribution after SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Print the value counts to verify
print("Value counts after SMOTE:")
print(y_train_resampled.value_counts())
# Out:
# Value counts after SMOTE:
# Class
# 0    199020
# 1    199020
# Name: count, dtype: int64

# %% [markdown]
# Randomsampling for Undersampling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Load your dataset (replace '/path/to/your/data.csv' with your actual file path)
df1 = pd.read_csv('/content/creditcard.csv')

# Copy the data
df5 = df1.copy()

# Separate features (only numeric columns) and target
numeric_cols = df5.select_dtypes(include='number').columns
X = df5[numeric_cols]
y = df5['Class']  # Assuming 'Class' is the column indicating fraud (1) or not (0)

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Perform Random Undersampling
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# Check the distribution after undersampling
plt.figure(figsize=(8, 6))
sns.countplot(x=y_train_resampled)
plt.title('Class Distribution after Random Undersampling')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Print the value counts to verify
print("Value counts after Random Undersampling:")
print(y_train_resampled.value_counts())
# Out:
# Value counts after Random Undersampling:
# Class
# 0    344
# 1    344
# Name: count, dtype: int64

# %% [markdown]
# 5. Feature Selection

# %%
import pandas as pd
from sklearn.feature_selection import f_classif

# Assuming X_train_resampled is numerical and not suitable for chi2 test
# Perform ANOVA F-value test
f_scores, p_values = f_classif(X_train_resampled, y_train_resampled)

# Create a DataFrame to display the results
f_results = pd.DataFrame({'Feature': X_train.columns, 'F-value': f_scores, 'P-value': p_values})
f_results.sort_values(by='F-value', ascending=False, inplace=True)

# Display the results
print("ANOVA F-value Test Results:")
print(f_results)
# Out:
# ANOVA F-value Test Results:
#    Feature     F-value        P-value
# 30   Class         inf   0.000000e+00
# 14     V14  905.876029  1.621304e-127
# 4       V4  775.552787  8.880984e-115
# 11     V11  609.902931   7.823160e-97
# 12     V12  601.846545   6.666100e-96
# 10     V10  444.374579   1.946623e-76
# 16     V16  386.613050   1.322167e-68
# 3       V3  343.897060   1.553976e-62
# 9       V9  332.801705   6.452046e-61
# 17     V17  326.084487   6.281528e-60
# 2       V2  232.752024   1.828449e-45
# 18     V18  204.794038   7.696930e-41
# 7       V7  202.258042   2.056198e-40
# 1       V1  157.951228   9.487198e-33
# 5       V5  124.269496   1.220651e-26
# 6       V6  112.335172   2.066844e-24
# 19     V19   54.975204   3.609112e-13
# 20     V20   20.805071   6.022857e-06
# 24     V24   16.049324   6.846066e-05
# 0     Time   13.294688   2.863058e-04
# 21     V21    9.735784   1.882919e-03
# 29  Amount    7.206446   7.439612e-03
# 28     V28    5.948053   1.498609e-02
# ...

# %% [markdown]
# 6. Dimensionality Reduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix

# Load your dataset
df1 = pd.read_csv('/content/creditcard.csv')

# Assuming 'Class' is the column indicating fraud (1) or not (0)
X = df1.drop('Class', axis=1)  # Features
y = df1['Class']  # Target

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Standardize the data before applying PCA
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Apply PCA
pca = PCA(n_components=0.95, random_state=42)  # Retain 95% of variance
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Print the number of components selected by PCA
print(f"Number of components selected by PCA: {pca.n_components_}")

# Display the explained variance ratio
print(f"Explained variance ratio by PCA components:\n{pca.explained_variance_ratio_}")

# Visualize the cumulative explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--')
plt.title('Cumulative Explained Variance Ratio by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()
# Out:
# Number of components selected by PCA: 17
# Explained variance ratio by PCA components:
# [0.39397332 0.09822952 0.06369827 0.05693615 0.04991687 0.04171445
#  0.038117   0.03583584 0.02932641 0.02844407 0.02534648 0.02194783
#  0.01971181 0.0183996  0.01467658 0.0124367  0.009916  ]

# %% [markdown]
# ML Classification

# %%
df10=df4.copy()
df10
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df10.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# KNN

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# Filter out numeric columns for X
numeric_cols = df10.select_dtypes(include='number').columns
X = df10[numeric_cols].drop('Class', axis=1)  # Exclude the target variable

# Define the target variable
y = df10['Class']

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the data (KNN is sensitive to the scale of the features)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # Start with a simple choice of k

# Train the model
knn.fit(X_train_scaled, y_train)

# Make predictions
y_pred = knn.predict(X_test_scaled)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.86      0.76      0.80       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion Matrix:
# [[85290    17]
#  [   33   103]]
