# %% [markdown]
# <a href="https://colab.research.google.com/github/sarvesh238327109/DataScience_Internship/blob/main/DS_Practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#create data for plotting
x = [0,1,2,3,4,5]
y = [0,1,4,9,16,25]

#the efault graph style for plot is a line
plt.plot(x, y)

#display the graph
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5])
plt.show()

# %%
import matplotlib.pyplot as plt

values = [5,6,3,7,2]
names = ["a", "b", "c", "d", "e"]
colors = ["red", "green", "blue", "yellow", "black"]

plt.bar(names, values, color = colors)
plt.show()

# %%
import matplotlib.pyplot as plt

#frequencies

ages=[2,5,70,40,30,45,50,45,43,40,44,60,7,13,57,18,90,77,32,21,20,40]
range = (0,101)  # Fixed the upper bound to include 100
bins = 11

plt.hist(ages, bins, range, color = 'green', histtype = 'bar', rwidth = 0.8)

plt.xlabel('ages')
plt.ylabel('No. of people')
plt.title('Histogram')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

plt.scatter(x, y, s=30, color="black", marker="^")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Scatter Plot")
plt.show()

# %%
import matplotlib.pyplot as plt

#defining labels+

activities = ['eat', 'sleep', 'work', 'play']

#portion covered by each label
slices = [3, 7, 8, 6]

#plotting the pie chart
plt.pie(slices, labels = activities, startangle = 90, shadow = True, explode = (0, 0.1, 0, 0), autopct = '%1.1f%%')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/Data.csv')

plt.bar(x,y)
plt.show()
